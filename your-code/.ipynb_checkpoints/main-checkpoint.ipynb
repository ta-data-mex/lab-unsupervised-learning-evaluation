# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from yellowbrick.cluster import KElbowVisualizer

# %%
plt.style.use('ggplot')

# %%
wine = datasets.load_wine()

# %%
X = pd.DataFrame(wine["data"], columns=wine["feature_names"])
y = pd.Series(wine["target"])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters=8)
kmeans.fit(X)
score = metrics.silhouette_score(X, kmeans.labels_, metric='euclidean', sample_size=len(X))
print(score)
# Out:
# 0.5398971441034137

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
score = metrics.silhouette_score(X, kmeans.labels_, metric='euclidean', sample_size=len(X))
print(score)
# Out:
# 0.5040308632722534

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
score = metrics.silhouette_score(X, kmeans.labels_, metric='euclidean', sample_size=len(X))
print(score)
# Out:
# 0.5711381937868844

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
metrics = ['distortion', 'silhouette', 'calinski_harabasz']

# %%
kmeans = KMeans()

for metric in metrics:
    visualizer = KElbowVisualizer(kmeans, k=(2,12), metric=metric)
    visualizer.fit(X)
    visualizer.show()

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
agglomerative_clustering = AgglomerativeClustering()
agglomerative_clustering.fit(X)


for metric in metrics:
    visualizer = KElbowVisualizer(agglomerative_clustering, k=(2,10), metric=metric)
    visualizer.fit(X)
    visualizer.show()

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=4)

# %%
wine_w_clusters = X
wine_w_clusters['cluster'] = kmeans.predict(X)
wine_w_clusters.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  cluster
# ...

# %%
sns.pairplot(data=wine_w_clusters, kind='scatter', hue='cluster')

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
pca = PCA(n_components = 2)
wine_pca_w_clusters = pd.DataFrame(data=pca.fit_transform(X), columns=['pc_1', 'pc_2'])
wine_pca_w_clusters.head(5)
# Out:
#          pc_1       pc_2
# 0  318.563051  21.508880
# 1  303.097491  -5.345665
# 2  438.061055  -6.557072
# 3  733.240061   0.172230
# 4  -11.571406  18.494242

# %%
kmeans = KMeans(n_clusters=4)
wine_pca_w_clusters['cluster'] = kmeans.fit_predict(wine_pca_w_clusters)
wine_pca_w_clusters
# Out:
#            pc_1       pc_2  cluster
# 0    318.563051  21.508880        0
# 1    303.097491  -5.345665        0
# 2    438.061055  -6.557072        2
# 3    733.240061   0.172230        2
# 4    -11.571406  18.494242        1
# ..          ...        ...      ...
# 173   -6.980189  -4.534960        1
# 174    3.131627   2.340745        1
# 175   88.458096  18.780467        0
# 176   93.456264  18.675003        0
# 177 -186.943217  -0.220349        1
#
# [178 rows x 3 columns]

# %%
sns.scatterplot(data=wine_pca_w_clusters, x='pc_1', y='pc_2', hue='cluster')
plt.xlabel('Principal Component 1', fontsize = 15)
plt.ylabel('Principal Component 2', fontsize = 15)
plt.title('2 Component PCA', fontsize = 20)
plt.show()

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.

# %%
list(X.columns)
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline',
#  'cluster']

# %%
fig, ax = plt.subplots(1, 4, figsize=(15, 7))
for i, perp in enumerate([5, 12, 30, 50]):
    tsne = TSNE(perplexity=perp,random_state=123)
    x_embedded = tsne.fit_transform(X)
    ax[i].scatter(x_embedded[:, 0], x_embedded[:, 1], c=wine_w_clusters['cluster'])
    ax[i].set_title("Perplexity = {}".format(perp))
    
plt.show()
