# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(context='notebook', style='whitegrid', palette='Spectral')

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

model = KMeans()
model.fit(X)

labels = model.labels_

score = silhouette_score(X, labels, metric='euclidean')
score
# Out:
# 0.5398971441034137

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
model_5 = KMeans(5)
model_5.fit(X)

labels_5 = model_5.labels_

score_5 = silhouette_score(X, labels_5, metric='euclidean')
score_5
# Out:
# 0.5489993239795691

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
model_3 = KMeans(3)
model_3.fit(X)

labels_3 = model_3.labels_

score_3 = silhouette_score(X, labels_3, metric='euclidean')
score_3
# Out:
# 0.5711381937868844

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
from yellowbrick.cluster import KElbowVisualizer

model = KMeans()
visualizer = KElbowVisualizer(model, k=(3,12))
visualizer.fit(X)
visualizer.poof();

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, metric='calinski_harabasz', k=(3,12))
visualizer.fit(X)
visualizer.poof();

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, metric='silhouette', k=(3,12))
visualizer.fit(X)
visualizer.poof();

# %%
from yellowbrick.cluster import SilhouetteVisualizer

model = KMeans(8, random_state=42)
visualizer = SilhouetteVisualizer(model, colors='yellowbrick')

visualizer.fit(X)
visualizer.poof()

# %%
model = KMeans(5, random_state=42)
visualizer = SilhouetteVisualizer(model, colors='yellowbrick')

visualizer.fit(X)
visualizer.poof()

# %%
model = KMeans(3, random_state=42)
visualizer = SilhouetteVisualizer(model, colors='yellowbrick')

visualizer.fit(X)
visualizer.poof()

# %%
from sklearn.metrics import adjusted_rand_score

print(f'Adjusted Rand Score for 8 clusters: {adjusted_rand_score(y, labels)}')
print(f'Adjusted Rand Score for 5 clusters: {adjusted_rand_score(y, labels_5)}')
print(f'Adjusted Rand Score for 3 clusters: {adjusted_rand_score(y, labels_3)}')
# Out:
# Adjusted Rand Score for 8 clusters: 0.19781277843153539
# Adjusted Rand Score for 5 clusters: 0.31158801033176253
# Adjusted Rand Score for 3 clusters: 0.37111371823084754

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
from sklearn.cluster import AgglomerativeClustering

model = AgglomerativeClustering(n_clusters=8)
model.fit(X)

labels = model.labels_

score = silhouette_score(X, labels, metric='euclidean')
score
# Out:
# 0.5299175684221904

# %%
model_5 = AgglomerativeClustering(n_clusters=5)
model_5.fit(X)

labels_5 = model_5.labels_

score_5 = silhouette_score(X, labels_5, metric='euclidean')
score_5
# Out:
# 0.5074843044233799

# %%
model_3 = AgglomerativeClustering(n_clusters=3)
model_3.fit(X)

labels_3 = model_3.labels_

score_3 = silhouette_score(X, labels_3, metric='euclidean')
score_3
# Out:
# 0.5644796401732074

# %%
model = AgglomerativeClustering()
visualizer = KElbowVisualizer(model, k=(3,12))
visualizer.fit(X)
visualizer.poof();

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, 
                              metric='calinski_harabasz', 
                              k=(3,12), 
                              locate_elbow=False)
visualizer.fit(X)
visualizer.poof();

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, metric='silhouette', k=(3,12))
visualizer.fit(X)
visualizer.poof();

# %%
print(f'Adjusted Rand Score for 8 clusters: {adjusted_rand_score(y, labels)}')
print(f'Adjusted Rand Score for 5 clusters: {adjusted_rand_score(y, labels_5)}')
print(f'Adjusted Rand Score for 3 clusters: {adjusted_rand_score(y, labels_3)}')
# Out:
# Adjusted Rand Score for 8 clusters: 0.21665810993831505
# Adjusted Rand Score for 5 clusters: 0.2153332245979518
# Adjusted Rand Score for 3 clusters: 0.36840191587483156

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
X.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
y_pred = kmeans.predict(X)


plt.figure(figsize=(12,7))
plt.scatter(np.array(X)[:,0], np.array(X)[:,1], c=y_pred)

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=50, alpha=0.75)

plt.show();

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca.fit(X)
pca_X = pca.transform(X)

kmeans = KMeans(n_clusters=2)
kmeans.fit(pca_X)
y_pred = kmeans.predict(pca_X)

plt.figure(figsize=(12,7))
plt.scatter(pca_X[:,0], pca_X[:,1], c=y_pred)

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=50, alpha=0.75)

plt.show();

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.

# %%
from sklearn.manifold import TSNE

fig, ax = plt.subplots(1, 4, figsize=(15, 7))
for i, perp in enumerate([5, 30, 50, 100]):
    tsne = TSNE(perplexity=perp)
    x_embedded = tsne.fit_transform(X)
    ax[i].scatter(x_embedded[:, 0], x_embedded[:, 1], c=y_pred)
    ax[i].set_title("Perplexity = {}".format(perp))
    
plt.show();
